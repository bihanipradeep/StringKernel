# %%
import os
import sys
import importlib
# %matplotlib notebook
from matplotlib import pyplot as plt
import numpy as np

# %%
sys.path.insert(0, os.path.abspath('../'))
from TextProcessing.CsvReader import CsvReader
import Constant as C
import Util as util
import MetricsUtil

# %%
importlib.reload(MetricsUtil)
# Out:
# <module 'MetricsUtil' from '/Users/pradeep/Files/ML/StringKernel/MetricsUtil.py'>

# %%
case_name = "case7"
purpose = "input"
print("Model Name")
print("Model", input())
# Out:
# Model Name
# hi
# Model hi

# %%
def plot_metrics(axs, case_name, purpose,color1,color2):
    metrics = MetricsUtil.get_metrics_data(case_name, purpose)
    max_len = len(metrics)
    for i in range(max_len):
        axs.set_title(purpose)
        axs.set_xlabel('N')
        x = metrics[i]["ns"]
        y = metrics[i]["f1_1"]
        y1 = metrics[i]["f1_2"]
        axs.scatter(x,y,c=color1)
        axs.scatter(x,y1,c=color2)
        for j in range(len(metrics[i]["ns"])):
            axs.annotate(str(metrics[i]["m_lambda"]), (x[j], y[j]))
            axs.annotate(str(metrics[i]["m_lambda"]), (x[j], y1[j]))

# %%
fig, axs = plt.subplots(1,2,figsize=(10, 5))
plot_metrics(axs[0] ,case_name, purpose, 'blue','red')
plot_metrics(axs[1] ,case_name, "test", 'blue','red')
plt.show()

# fig, axs = plt.subplots(2, 5,figsize=(25, 10))
# plot_metrics(axs , MetricsUtil.get_metrics_data(case_name,"test"),'blue','red')
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#         plt1.annotate(metrics[i]["m_lambda"], xy=(x[i], y[i])) 
#         plt1.xlabel("N")
#         plt1.ylabel("precision")
