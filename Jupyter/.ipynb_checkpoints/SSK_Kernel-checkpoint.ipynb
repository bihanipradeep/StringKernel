# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))
import importlib

# %%
from TextProcessing.CsvReader import CsvReader
import Constant as C
import Util as util
import MetricsUtil
from matplotlib import pyplot as plt 
import numpy as np
importlib.reload(MetricsUtil)
# Out:
# <module 'MetricsUtil' from '/Users/pradeep/Files/ML/StringKernel/MetricsUtil.py'>

# %%
case_name = "case1"
purpose = "input"

# %%
def plot_metrics(axs, metrics):
    max_len = len(metrics)
    for i in range(max_len):
        axi = axs[int(i/5),i%5]
        axi.set_title('Lambda : '+str(metrics[i]["m_lambda"]))
        axi.set_xlabel('N')
        x = metrics[i]["ns"]
        y = metrics[i]["precision1"]
        axi.scatter(x,y)

# %%
fig, axs = plt.subplots(2, 5,figsize=(25, 10))
plot_metrics(axs , MetricsUtil.get_metrics_data(case_name,purpose), metrices2)
plt.show()

fig, axs = plt.subplots(2, 5,figsize=(25, 10))
plot_metrics(axs , MetricsUtil.get_metrics_data(case_name,"test"), metrices2)
plt.show()
# Out:
# ['/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_50_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_90_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_70_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_30_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_10_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_40_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_80_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_60_input', '/Users/pradeep/Files/ML/StringKernel/data/result/case1/case1_20_input']
# ...

# %%
#         plt1.annotate(metrics[i]["m_lambda"], xy=(x[i], y[i])) 
#         plt1.xlabel("N")
#         plt1.ylabel("precision")
